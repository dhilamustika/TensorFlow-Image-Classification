# %%
# download the chessman dataset
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2023-03-04 06:35:29--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2023-03-04 06:35:29--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   118MB/s    in 0.5s
#
# 2023-03-04 06:35:30 (118 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
# extract the dataset
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
# list of directories in the data set
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Queen', 'Pawn', 'Rook', 'Knight', 'Bishop', 'King']

# %%
# check the number of files in each directory
print('total Knight images: ', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
print('total Pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total Bishop images: ', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Bishop')))
print('total Queen images: ', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Queen')))
print('total Rook images: ', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Rook')))
print('total King images: ', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
# Out:
# total Knight images:  106
# total Pawn images : 107
# total Bishop images:  87
# total Queen images:  78
# total Rook images:  102
# total King images:  76

# %%
# display some sample images
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
# based on the output in the previous cell, the number of images is different in each directory
# in addition, the format and size of the images are also not the same
# to solve this problem, we will try to apply image augmentation

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   fill_mode='nearest',
                                   validation_split=0.1)  # set validation split

# %%
# image generator

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=8,
    class_mode='categorical',
    subset='training')  # set as training data

validation_generator = train_datagen.flow_from_directory(
    train_dir,  # same directory as training data
    target_size=(150,150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
# build a Convolutional Neural Network (CNN) model

'''
   # using 3 convolution layers and 2 hidden layers with 512 and 256 perceptron units
   
'''

import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 9,642,086
# Trainable params: 9,642,086
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model 
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# train the model
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=50,
                    verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 54s - loss: 1.8545 - accuracy: 0.1864 - val_loss: 1.7846 - val_accuracy: 0.1923 - 54s/epoch - 855ms/step
# Epoch 2/50
# 63/63 - 50s - loss: 1.7895 - accuracy: 0.1683 - val_loss: 1.7772 - val_accuracy: 0.2308 - 50s/epoch - 787ms/step
# Epoch 3/50
# 63/63 - 48s - loss: 1.7851 - accuracy: 0.1924 - val_loss: 1.7799 - val_accuracy: 0.1923 - 48s/epoch - 759ms/step
# Epoch 4/50
# 63/63 - 51s - loss: 1.7834 - accuracy: 0.2084 - val_loss: 1.7702 - val_accuracy: 0.2308 - 51s/epoch - 811ms/step
# Epoch 5/50
# 63/63 - 49s - loss: 1.7513 - accuracy: 0.2285 - val_loss: 1.7551 - val_accuracy: 0.2308 - 49s/epoch - 785ms/step
# Epoch 6/50
# 63/63 - 57s - loss: 1.7479 - accuracy: 0.2265 - val_loss: 1.8071 - val_accuracy: 0.2692 - 57s/epoch - 909ms/step
# Epoch 7/50
# 63/63 - 52s - loss: 1.7268 - accuracy: 0.2665 - val_loss: 1.7662 - val_accuracy: 0.2500 - 52s/epoch - 820ms/step
# Epoch 8/50
# 63/63 - 50s - loss: 1.6898 - accuracy: 0.2846 - val_loss: 1.7265 - val_accuracy: 0.2500 - 50s/epoch - 791ms/step
# Epoch 9/50
# 63/63 - 53s - loss: 1.5977 - accuracy: 0.3587 - val_loss: 1.8079 - val_accuracy: 0.2500 - 53s/epoch - 836ms/step
# Epoch 10/50
# 63/63 - 48s - loss: 1.5492 - accuracy: 0.3768 - val_loss: 1.7459 - val_accuracy: 0.2500 - 48s/epoch - 759ms/step
# Epoch 11/50
# 63/63 - 51s - loss: 1.4920 - accuracy: 0.3968 - val_loss: 1.6066 - val_accuracy: 0.3269 - 51s/epoch - 814ms/step
# Epoch 12/50
# 63/63 - 49s - loss: 1.4495 - accuracy: 0.4008 - val_loss: 1.6762 - val_accuracy: 0.2885 - 49s/epoch - 785ms/step
# Epoch 13/50
# 63/63 - 49s - loss: 1.3931 - accuracy: 0.4389 - val_loss: 1.4603 - val_accuracy: 0.4615 - 49s/epoch - 777ms/step
# Epoch 14/50
# 63/63 - 50s - loss: 1.3210 - accuracy: 0.4930 - val_loss: 1.6021 - val_accuracy: 0.3077 - 50s/epoch - 801ms/step
# Epoch 15/50
# 63/63 - 49s - loss: 1.3028 - accuracy: 0.4930 - val_loss: 1.4488 - val_accuracy: 0.4615 - 49s/epoch - 777ms/step
# Epoch 16/50
# 63/63 - 61s - loss: 1.2546 - accuracy: 0.5070 - val_loss: 1.4815 - val_accuracy: 0.3654 - 61s/epoch - 969ms/step
# Epoch 17/50
# 63/63 - 49s - loss: 1.2090 - accuracy: 0.4990 - val_loss: 1.4302 - val_accuracy: 0.4038 - 49s/epoch - 781ms/step
# Epoch 18/50
# 63/63 - 48s - loss: 1.1873 - accuracy: 0.5170 - val_loss: 1.4547 - val_accuracy: 0.3654 - 48s/epoch - 767ms/step
# Epoch 19/50
# 63/63 - 52s - loss: 1.0996 - accuracy: 0.5752 - val_loss: 1.5617 - val_accuracy: 0.3462 - 52s/epoch - 817ms/step
# Epoch 20/50
# 63/63 - 49s - loss: 1.1235 - accuracy: 0.5772 - val_loss: 1.5225 - val_accuracy: 0.3462 - 49s/epoch - 779ms/step
# Epoch 21/50
# 63/63 - 51s - loss: 1.0244 - accuracy: 0.6032 - val_loss: 1.4469 - val_accuracy: 0.4423 - 51s/epoch - 813ms/step
# Epoch 22/50
# 63/63 - 51s - loss: 0.9535 - accuracy: 0.6533 - val_loss: 1.4887 - val_accuracy: 0.3846 - 51s/epoch - 809ms/step
# Epoch 23/50
# 63/63 - 55s - loss: 0.9871 - accuracy: 0.6232 - val_loss: 1.4680 - val_accuracy: 0.3654 - 55s/epoch - 869ms/step
# Epoch 24/50
# 63/63 - 49s - loss: 0.9344 - accuracy: 0.6253 - val_loss: 1.4405 - val_accuracy: 0.4423 - 49s/epoch - 783ms/step
# Epoch 25/50
# 63/63 - 57s - loss: 0.9198 - accuracy: 0.6673 - val_loss: 1.3737 - val_accuracy: 0.4231 - 57s/epoch - 909ms/step
# Epoch 26/50
# 63/63 - 48s - loss: 0.9174 - accuracy: 0.6633 - val_loss: 1.4331 - val_accuracy: 0.5000 - 48s/epoch - 766ms/step
# Epoch 27/50
# 63/63 - 48s - loss: 0.8628 - accuracy: 0.6633 - val_loss: 1.4967 - val_accuracy: 0.4615 - 48s/epoch - 766ms/step
# Epoch 28/50
# 63/63 - 48s - loss: 0.8992 - accuracy: 0.6593 - val_loss: 1.3750 - val_accuracy: 0.5000 - 48s/epoch - 756ms/step
# Epoch 29/50
# 63/63 - 48s - loss: 0.8115 - accuracy: 0.7174 - val_loss: 1.4187 - val_accuracy: 0.4231 - 48s/epoch - 765ms/step
# Epoch 30/50
# 63/63 - 49s - loss: 0.7782 - accuracy: 0.7234 - val_loss: 1.3457 - val_accuracy: 0.5000 - 49s/epoch - 777ms/step
# Epoch 31/50
# 63/63 - 48s - loss: 0.6762 - accuracy: 0.7675 - val_loss: 1.5343 - val_accuracy: 0.5000 - 48s/epoch - 759ms/step
# Epoch 32/50
# 63/63 - 47s - loss: 0.7312 - accuracy: 0.7194 - val_loss: 1.4688 - val_accuracy: 0.4231 - 47s/epoch - 754ms/step
# Epoch 33/50
# 63/63 - 48s - loss: 0.6307 - accuracy: 0.7655 - val_loss: 1.7886 - val_accuracy: 0.4231 - 48s/epoch - 760ms/step
# Epoch 34/50
# 63/63 - 47s - loss: 0.6985 - accuracy: 0.7214 - val_loss: 1.3665 - val_accuracy: 0.5577 - 47s/epoch - 741ms/step
# Epoch 35/50
# 63/63 - 52s - loss: 0.6628 - accuracy: 0.7515 - val_loss: 1.2393 - val_accuracy: 0.5385 - 52s/epoch - 825ms/step
# Epoch 36/50
# 63/63 - 45s - loss: 0.6498 - accuracy: 0.7675 - val_loss: 1.6168 - val_accuracy: 0.5385 - 45s/epoch - 718ms/step
# Epoch 37/50
# 63/63 - 46s - loss: 0.6106 - accuracy: 0.7896 - val_loss: 1.3451 - val_accuracy: 0.5192 - 46s/epoch - 723ms/step
# Epoch 38/50
# 63/63 - 46s - loss: 0.4538 - accuracy: 0.8337 - val_loss: 1.6627 - val_accuracy: 0.5769 - 46s/epoch - 724ms/step
# Epoch 39/50
# 63/63 - 45s - loss: 0.5540 - accuracy: 0.7916 - val_loss: 1.5473 - val_accuracy: 0.4615 - 45s/epoch - 712ms/step
# Epoch 40/50
# 63/63 - 45s - loss: 0.5798 - accuracy: 0.8076 - val_loss: 1.2738 - val_accuracy: 0.5769 - 45s/epoch - 710ms/step
# Epoch 41/50
# 63/63 - 46s - loss: 0.5569 - accuracy: 0.7896 - val_loss: 1.5994 - val_accuracy: 0.4808 - 46s/epoch - 728ms/step
# Epoch 42/50
# 63/63 - 46s - loss: 0.4978 - accuracy: 0.8176 - val_loss: 1.8215 - val_accuracy: 0.4423 - 46s/epoch - 731ms/step
# Epoch 43/50
# 63/63 - 45s - loss: 0.5068 - accuracy: 0.8176 - val_loss: 1.1347 - val_accuracy: 0.5577 - 45s/epoch - 721ms/step
# Epoch 44/50
# 63/63 - 44s - loss: 0.4435 - accuracy: 0.8417 - val_loss: 1.6429 - val_accuracy: 0.4423 - 44s/epoch - 703ms/step
# Epoch 45/50
# 63/63 - 45s - loss: 0.4546 - accuracy: 0.8357 - val_loss: 1.5667 - val_accuracy: 0.4038 - 45s/epoch - 711ms/step
# Epoch 46/50
# 63/63 - 45s - loss: 0.3932 - accuracy: 0.8577 - val_loss: 1.5509 - val_accuracy: 0.4231 - 45s/epoch - 714ms/step
# Epoch 47/50
# 63/63 - 45s - loss: 0.3975 - accuracy: 0.8657 - val_loss: 1.7886 - val_accuracy: 0.4808 - 45s/epoch - 707ms/step
# Epoch 48/50
# 63/63 - 45s - loss: 0.3999 - accuracy: 0.8557 - val_loss: 1.6304 - val_accuracy: 0.4615 - 45s/epoch - 709ms/step
# Epoch 49/50
# 63/63 - 46s - loss: 0.4494 - accuracy: 0.8377 - val_loss: 1.4047 - val_accuracy: 0.5192 - 46s/epoch - 724ms/step
# Epoch 50/50
# 63/63 - 46s - loss: 0.3717 - accuracy: 0.8717 - val_loss: 1.7753 - val_accuracy: 0.5192 - 46s/epoch - 727ms/step

# %%
# plot the accuracy of the model
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# plot the loss of the model
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
